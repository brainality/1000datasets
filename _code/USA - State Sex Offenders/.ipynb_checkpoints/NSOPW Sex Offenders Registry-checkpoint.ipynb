# %% [markdown]
# #### USA   National Sex Offender Public Website (NSOPW)
# NSOPW provides public access to sex offenders data in 50 states in USA.The code below scrapes website by State name and first letters of first and last names to get offender name, age, profile link and addresses.
#
# https://www.nsopw.gov/search-public-sex-offender-registries

# %% [markdown]
# ### Import modules

# %%
import requests
from bs4 import BeautifulSoup
from lxml import html
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
from requests.structures import CaseInsensitiveDict
from selenium.webdriver.common.alert import Alert 
from selenium.webdriver.support.ui import Select
import time
import traceback
import re
import time
from pathlib import Path

# %% [markdown]
# ### Global variables

# %%
dictOffenders_final = dict()
dictErrors = dict()

# %% [markdown]
# ### Functions

# %%
from itertools import product

def get_alphabet():
    l1 = list(map(chr,range(97,123)))
    ab = list(product(l1, repeat=2))
    ln = len(ab)
    return ab,ln

def set_field_value(firstNameKey, lastNameKey):
    inputName = driver.find_element(By.XPATH,'//*[@id="firstname"]')
    inputLastName = driver.find_element(By.XPATH,'//*[@id="lastname"]')
    
    inputName.clear()
    inputLastName.clear()
    
    inputName.send_keys(firstNameKey)
    inputLastName.send_keys(lastNameKey)
    
    return f"SET First key {firstNameKey} and LastKey {lastNameKey}"

def set_state_abbr(state_abbr):
    stateList = Select(driver.find_element(By.XPATH,'//*[@id="stateterritory"]'))
    stateList.select_by_value(state_abbr)
    return state_abbr

def show_all_entries():
    showEntries = Select(driver.find_element(By.NAME,'nsopwdt_length'))
    showEntries.select_by_value("-1")
    
    numResults  = driver.find_element(By.XPATH,'//*[@id="nsopwdt_info"]')
    result = re.search('of(.*)entries', numResults.text)
    NumRecords = int(result.group(1))
    return NumRecords



def get_entries_data(num_entries,f,l):
    
    try:
        i = 0
        Ids = []
        Names = []
        Ages = []
        Aliases = []
        Addresses = []
        Links = []
        Characters = []

        for el in range(1,num_entries+1):
            Name = driver.find_element(By.XPATH,'//*[@id="nsopwdt"]/tbody/tr['+str(el)+']/td[1]').text.replace("\n"," ")
            Age = driver.find_element(By.XPATH,'//*[@id="nsopwdt"]/tbody/tr['+str(el)+']/td[2]').text.replace("\n"," ")
            Address = driver.find_element(By.XPATH,'//*[@id="nsopwdt"]/tbody/tr['+str(el)+']/td[4]').text.replace("\n"," ")

            href=driver.find_element(By.XPATH,'//*[@id="nsopwdt"]/tbody/tr['+str(el)+']/td[1]/a').get_attribute('href')
            resultId = re.search('OfndrID=(.*)&AgencyID', href)
            Ids.append(resultId.group(1))
            Names.append(Name)
            Ages.append(Age)
            Addresses.append(Address)
            Links.append(href)
            Characters.append([f,l])
            i=i+1
    except :
        print(traceback.format_exc())

    return Ids,Names,Ages,Addresses,Links,Characters

# %% [markdown]
# ### Start Selenium

# %%
driver = webdriver.Chrome()

URL = "https://www.nsopw.gov/search-public-sex-offender-registries"
driver.get(URL)

driver.find_element(By.XPATH,'//*[@id="confirmBtn"]').click()
driver.implicitly_wait(10) # seconds
# Out:
# https://www.nsopw.gov/search-public-sex-offender-registries

# %% [markdown]
# ### Run code

# %%
###Main 
alph,length = get_alphabet()
total_cumulative_time =0
total_start_time = time.time()
char_list = list()

for x in range(0,length):
#for x in range(397,length):

    loop_start_time = time.time()
    
    set_field_value(alph[x][0],alph[x][1])
    
    stateAbbrv = set_state_abbr('MD')
    
    time.sleep(2) # seconds

    driver.find_element(By.XPATH,'//*[@id="searchbynamezip"]').click()
    driver.implicitly_wait(13) # seconds

    time.sleep(11) # seconds
    try:
        numEntries = show_all_entries()
    except AttributeError:
        print(f"AttributeError: {alph[x][0]} and {alph[x][1]}")
        char_list.append([alph[x][0],alph[x][1]])
        dictErrors[stateAbbrv]=char_list
        pass
    driver.implicitly_wait(13) # seconds

    
    id,name,age,address,link,character=get_entries_data(numEntries,alph[x][0],alph[x][1])
    time.sleep(2) # seconds
    

    
    #Put lists together into dictionary
    nms = list(zip(name,age, address,link,character))
    dictOffenders = dict(zip(id,nms))
    #Send data to global dictionary
    #records = records+len(dictOffenders)
    dictOffenders_final.update(dictOffenders)
    print(f"total records processed {len(dictOffenders_final)}")
    
    #go back to search page
    driver.find_element(By.XPATH,'//*[@id="nsopwsearchfilter"]').click()
    time.sleep(2) # seconds
    
    loop_end_time = time.time()-loop_start_time
    total_cumulative_time = total_cumulative_time+loop_end_time
    #print(f"loop end time {loop_end_time}")
    print(f"total cumulative time  {total_cumulative_time}")
    print(f"----------------------------------------------------")
    
total_elapsed_time = time.time()-total_start_time
print(f"total elapsed time  {total_elapsed_time}")

df = pd.DataFrame.from_dict(dictOffenders_final,orient='index',columns = ['Name','Age','Address','Link','Characters'])
df.to_csv('Maryland_Offenders_25102024.csv')
# Out:
# total records processed 5377
# total cumulative time  21.70471692085266
# ----------------------------------------------------
# total records processed 5378
# total cumulative time  39.673781633377075
# ----------------------------------------------------
# total records processed 5381
# total cumulative time  58.841325998306274
# ----------------------------------------------------
# total records processed 5385
# total cumulative time  76.9434323310852
# ----------------------------------------------------
# total records processed 5392
# total cumulative time  96.75036597251892
# ----------------------------------------------------
# total records processed 5405
# total cumulative time  117.5794882774353
# ----------------------------------------------------
# total records processed 5406
# total cumulative time  135.6541292667389
# ----------------------------------------------------
# total records processed 5411
# total cumulative time  154.0377802848816
# ----------------------------------------------------
# total records processed 5419
# total cumulative time  174.1499147415161
# ----------------------------------------------------
# total records processed 5420
# total cumulative time  192.39185452461243
# ----------------------------------------------------
# total records processed 5425
# total cumulative time  210.86937618255615
# ----------------------------------------------------
# total records processed 5440
# total cumulative time  232.11849164962769
# ----------------------------------------------------
# total records processed 5449
# total cumulative time  251.8274631500244
# ----------------------------------------------------
# total records processed 5449
# total cumulative time  269.8139569759369
# ----------------------------------------------------
# total records processed 5451
# total cumulative time  288.0828261375427
# ----------------------------------------------------
# total records processed 5462
# total cumulative time  308.210960149765
# ----------------------------------------------------
# total records processed 5463
# total cumulative time  326.4117522239685
# ----------------------------------------------------
# total records processed 5463
# total cumulative time  344.43382835388184
# ----------------------------------------------------
# total records processed 5463
# total cumulative time  362.6902415752411
# ----------------------------------------------------
# total records processed 5463
# total cumulative time  380.70457768440247
# ----------------------------------------------------
# total records processed 5463
# total cumulative time  398.6151170730591
# ----------------------------------------------------
# total records processed 5464
# total cumulative time  417.03250789642334
# ----------------------------------------------------
# total records processed 5466
# total cumulative time  434.99407267570496
# ----------------------------------------------------
# total records processed 5466
# total cumulative time  452.5557699203491
# ----------------------------------------------------
# total records processed 5466
# total cumulative time  470.2649519443512
# ----------------------------------------------------
# total records processed 5468
# total cumulative time  487.97807788848877
# ----------------------------------------------------
# total records processed 5468
# total cumulative time  505.4572231769562
# ----------------------------------------------------
# total records processed 5468
# total cumulative time  523.0224716663361
# ----------------------------------------------------
# total records processed 5468
# total cumulative time  541.2106513977051
# ----------------------------------------------------
# total records processed 5471
# total cumulative time  559.7591614723206
# ----------------------------------------------------
# total records processed 5472
# total cumulative time  577.947879076004
# ----------------------------------------------------
# total records processed 5472
# total cumulative time  595.7424445152283
# ----------------------------------------------------
# total records processed 5472
# total cumulative time  613.544438123703
# ----------------------------------------------------
# total records processed 5472
# total cumulative time  631.0038652420044
# ----------------------------------------------------
# total records processed 5472
# total cumulative time  648.7853977680206
# ----------------------------------------------------
# total records processed 5472
# total cumulative time  666.2492830753326
# ----------------------------------------------------
# total records processed 5473
# total cumulative time  683.9090812206268
# ----------------------------------------------------
# total records processed 5476
# total cumulative time  702.3284287452698
# ----------------------------------------------------
# total records processed 5476
# total cumulative time  720.3318548202515
# ----------------------------------------------------
# total records processed 5476
# total cumulative time  738.3394777774811
# ----------------------------------------------------
# total records processed 5476
# total cumulative time  756.36421251297
# ----------------------------------------------------
# total records processed 5477
# total cumulative time  774.5502696037292
# ----------------------------------------------------
# total records processed 5477
# total cumulative time  792.733151435852
# ----------------------------------------------------
# total records processed 5478
# total cumulative time  810.9138343334198
# ----------------------------------------------------
# total records processed 5478
# total cumulative time  828.9340713024139
# ----------------------------------------------------
# total records processed 5492
# total cumulative time  851.2750566005707
# ----------------------------------------------------
# total records processed 5572
# total cumulative time  892.3417518138885
# ----------------------------------------------------
# total records processed 5606
# total cumulative time  919.649322271347
# ----------------------------------------------------
# total records processed 5623
# total cumulative time  944.3966000080109
# ----------------------------------------------------
# total records processed 5634
# total cumulative time  964.9938218593597
# ----------------------------------------------------
# total records processed 5647
# total cumulative time  985.2074892520905
# ----------------------------------------------------
# total records processed 5682
# total cumulative time  1012.183431148529
# ----------------------------------------------------
# total records processed 5732
# total cumulative time  1044.3900904655457
# ----------------------------------------------------
# total records processed 5737
# total cumulative time  1063.119333744049
# ----------------------------------------------------
# total records processed 5756
# total cumulative time  1086.8349595069885
# ----------------------------------------------------
# total records processed 5774
# total cumulative time  1108.2950823307037
# ----------------------------------------------------
# total records processed 5797
# total cumulative time  1131.436020374298
# ----------------------------------------------------
# total records processed 5851
# total cumulative time  1163.8232712745667
# ----------------------------------------------------
# total records processed 5856
# total cumulative time  1183.8785877227783
# ----------------------------------------------------
# total records processed 5864
# total cumulative time  1203.95321559906
# ----------------------------------------------------
# total records processed 5885
# total cumulative time  1227.1939356327057
# ----------------------------------------------------
# total records processed 5885
# total cumulative time  1244.998594045639
# ----------------------------------------------------
# total records processed 5913
# total cumulative time  1272.5348145961761
# ----------------------------------------------------
# total records processed 5972
# total cumulative time  1307.0176572799683
# ----------------------------------------------------
# total records processed 5988
# total cumulative time  1331.6338279247284
# ----------------------------------------------------
# total records processed 5989
# total cumulative time  1349.5106899738312
# ----------------------------------------------------
# total records processed 5996
# total cumulative time  1367.7780802249908
# ----------------------------------------------------
# total records processed 6036
# total cumulative time  1398.5781247615814
# ----------------------------------------------------
# total records processed 6036
# total cumulative time  1417.6225028038025
# ----------------------------------------------------
# total records processed 6037
# total cumulative time  1435.471050977707
# ----------------------------------------------------
# total records processed 6037
# total cumulative time  1452.9392220973969
# ----------------------------------------------------
# total records processed 6052
# total cumulative time  1474.981419801712
# ----------------------------------------------------
# total records processed 6089
# total cumulative time  1502.6620378494263
# ----------------------------------------------------
# total records processed 6112
# total cumulative time  1528.977329492569
# ----------------------------------------------------
# total records processed 6125
# total cumulative time  1550.2667217254639
# ----------------------------------------------------
# total records processed 6129
# total cumulative time  1568.629468202591
# ----------------------------------------------------
# total records processed 6138
# total cumulative time  1586.8647592067719
# ----------------------------------------------------
# total records processed 6148
# total cumulative time  1607.5792083740234
# ----------------------------------------------------
# total records processed 6172
# total cumulative time  1630.6848738193512
# ----------------------------------------------------
# total records processed 6172
# total cumulative time  1648.4875602722168
# ----------------------------------------------------
# total records processed 6183
# total cumulative time  1669.171940088272
# ----------------------------------------------------
# total records processed 6193
# total cumulative time  1687.9423940181732
# ----------------------------------------------------
# total records processed 6202
# total cumulative time  1707.447343826294
# ----------------------------------------------------
# total records processed 6231
# total cumulative time  1732.8419976234436
# ----------------------------------------------------
# total records processed 6236
# total cumulative time  1752.3054490089417
# ----------------------------------------------------
# total records processed 6242
# total cumulative time  1770.5706050395966
# ----------------------------------------------------
# total records processed 6266
# total cumulative time  1794.2796473503113
# ----------------------------------------------------
# total records processed 6268
# total cumulative time  1812.285957813263
# ----------------------------------------------------
# total records processed 6281
# total cumulative time  1833.7226886749268
# ----------------------------------------------------
# total records processed 6314
# total cumulative time  1861.4573233127594
# ----------------------------------------------------
# total records processed 6327
# total cumulative time  1882.013505935669
# ----------------------------------------------------
# total records processed 6328
# total cumulative time  1899.8517174720764
# ----------------------------------------------------
# total records processed 6331
# total cumulative time  1918.1467399597168
# ----------------------------------------------------
# total records processed 6354
# total cumulative time  1942.1691598892212
# ----------------------------------------------------
# total records processed 6354
# total cumulative time  1960.200822353363
# ----------------------------------------------------
# total records processed 6356
# total cumulative time  1978.0321700572968
# ----------------------------------------------------
# total records processed 6358
# total cumulative time  1996.0330770015717
# ----------------------------------------------------
# total records processed 6374
# total cumulative time  2017.9608492851257
# ----------------------------------------------------
# total records processed 6430
# total cumulative time  2051.146029472351
# ----------------------------------------------------
# total records processed 6459
# total cumulative time  2079.1617760658264
# ----------------------------------------------------
# total records processed 6484
# total cumulative time  2100.0513038635254
# ----------------------------------------------------
# total records processed 6488
# total cumulative time  2119.3768026828766
# ----------------------------------------------------
# total records processed 6499
# total cumulative time  2139.981741666794
# ----------------------------------------------------
# total records processed 6519
# total cumulative time  2162.369138479233
# ----------------------------------------------------
# total records processed 6554
# total cumulative time  2189.032907485962
# ----------------------------------------------------
# total records processed 6556
# total cumulative time  2206.972495317459
# ----------------------------------------------------
# total records processed 6576
# total cumulative time  2232.1795830726624
# ----------------------------------------------------
# total records processed 6592
# total cumulative time  2252.4189705848694
# ----------------------------------------------------
# total records processed 6600
# total cumulative time  2271.6827199459076
# ----------------------------------------------------
# total records processed 6635
# total cumulative time  2299.5014271736145
# ----------------------------------------------------
# total records processed 6643
# total cumulative time  2320.643496274948
# ----------------------------------------------------
# total records processed 6646
# total cumulative time  2339.391364812851
# ----------------------------------------------------
# total records processed 6664
# total cumulative time  2362.7307505607605
# ----------------------------------------------------
# total records processed 6665
# total cumulative time  2380.948306083679
# ----------------------------------------------------
# total records processed 6680
# total cumulative time  2403.1421558856964
# ----------------------------------------------------
# total records processed 6711
# total cumulative time  2433.4116072654724
# ----------------------------------------------------
# total records processed 6731
# total cumulative time  2458.6458485126495
# ----------------------------------------------------
# total records processed 6731
# total cumulative time  2476.798201084137
# ----------------------------------------------------
# total records processed 6732
# total cumulative time  2495.1702992916107
# ----------------------------------------------------
# total records processed 6766
# total cumulative time  2523.6782574653625
# ----------------------------------------------------
# total records processed 6766
# total cumulative time  2542.368689060211
# ----------------------------------------------------
# total records processed 6767
# total cumulative time  2560.76872587204
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2579.17067694664
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2596.9482486248016
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2614.5314292907715
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2632.331510782242
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2649.7857949733734
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2667.876932859421
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2685.7957303524017
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2703.825037956238
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2721.83069396019
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2739.6426701545715
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2757.4437596797943
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2774.8509452342987
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2792.4277877807617
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2810.432163953781
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2827.7057700157166
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2845.485205411911
# ----------------------------------------------------
# total records processed 6768
# total cumulative time  2862.9390864372253
# ----------------------------------------------------
# total records processed 6768
